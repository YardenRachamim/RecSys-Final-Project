# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # S-POP training

# %% [markdown]
# **Train s-pop model on YOOchoose data**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train_s_pop.py"
# Out:
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/valid.txt
# 100% 15324/15324 [01:50<00:00, 138.77it/s]
# recall: 0.2692404021610791, mrr: 0.17937729272376557

# %% [markdown]
# **Train s-pop model on diginetica data**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train_s_pop.py" --data_folder "/content/drive/MyDrive/RecSys/FinalProject/data/digenetica"
# Out:
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/valid.txt
# 100% 2175/2175 [00:16<00:00, 128.87it/s]
# recall: 0.22701983551040156, mrr: 0.14599364415085078

# %% [markdown]
# # GRU4REC (One direction)

# %% [markdown]
# **Train one direction GRU4REC model, on YOOchoose data**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train.py" --data_folder '/content/drive/MyDrive/RecSys/FinalProject/data/youchoose' --n_epochs "5" --checkpoint_dir '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_yoochhose/one direction'
# Out:
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/valid.txt
# PARAMETER----------
# BATCH_SIZE=50
# CHECKPOINT_DIR=/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_yoochhose/one direction/02181809
# CUDA=True
# DATA_FOLDER=/content/drive/MyDrive/RecSys/FinalProject/data/youchoose
# DROPOUT_HIDDEN=0.5
# DROPOUT_INPUT=0
# EMBEDDING_DIM=-1
# EPS=1e-06
# FINAL_ACT=tanh
# HIDDEN_SIZE=100
# IS_BIDIRECTIONAL=False
# K_EVAL=20
# LOSS_TYPE=TOP1-max
# LR=0.01
# MODEL_NAME=GRU4REC-CrossEntropy
# MOMENTUM=0
# N_EPOCHS=5
# NUM_LAYERS=1
# OPTIMIZER_TYPE=Adagrad
# SAVE_DIR=models
# SEED=22
# SIGMA=None
# TIME_SORT=False
# TRAIN_DATA=train.txt
# VALID_DATA=valid.txt
# WEIGHT_DECAY=0
# -------------------
# ...

# %% [markdown]
# **Train one direction GRU4REC on Digenetica data**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train.py" --data_folder '/content/drive/MyDrive/RecSys/FinalProject/data/digenetica' --n_epochs "10" --num_layers "1" --batch_size "512"  --hidden_size "1000" --lr "0.03" --loss_type "TOP1" --checkpoint_dir '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/one direction'
# Out:
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/valid.txt
# PARAMETER----------
# BATCH_SIZE=512
# CHECKPOINT_DIR=/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/one direction/02190941
# CUDA=True
# DATA_FOLDER=/content/drive/MyDrive/RecSys/FinalProject/data/digenetica
# DROPOUT_HIDDEN=0.5
# DROPOUT_INPUT=0
# EMBEDDING_DIM=-1
# EPS=1e-06
# FINAL_ACT=tanh
# HIDDEN_SIZE=1000
# IS_BIDIRECTIONAL=False
# K_EVAL=20
# LOSS_TYPE=TOP1
# LR=0.03
# MODEL_NAME=GRU4REC-CrossEntropy
# MOMENTUM=0
# N_EPOCHS=10
# NUM_LAYERS=1
# OPTIMIZER_TYPE=Adagrad
# SAVE_DIR=models
# SEED=22
# SIGMA=None
# TIME_SORT=False
# TRAIN_DATA=train.txt
# VALID_DATA=valid.txt
# WEIGHT_DECAY=0
# -------------------
# ...

# %% [markdown]
# # Bidirectional GRU4REC (Our suggested model)

# %% [markdown]
# **Train Bidirection GRU4REC on YOOCHOOSE data set**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train.py" --data_folder '/content/drive/MyDrive/RecSys/FinalProject/data/digenetica' --n_epochs "5" --checkpoint_dir '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_yoochhose/bi-directional' --is_bidirectional

# %% [markdown]
# **Train Bidirection GRU4REC on Digenetica data set**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train.py" --data_folder '/content/drive/MyDrive/RecSys/FinalProject/data/digenetica' --n_epochs "10" --num_layers "1" --batch_size "512"  --hidden_size "1000" --lr "0.03" --loss_type "TOP1" --is_bidirectional --checkpoint_dir '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/bi-directional'
# Out:
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/valid.txt
# PARAMETER----------
# BATCH_SIZE=512
# CHECKPOINT_DIR=/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/bi-directional/02191031
# CUDA=True
# DATA_FOLDER=/content/drive/MyDrive/RecSys/FinalProject/data/digenetica
# DROPOUT_HIDDEN=0.5
# DROPOUT_INPUT=0
# EMBEDDING_DIM=-1
# EPS=1e-06
# FINAL_ACT=tanh
# HIDDEN_SIZE=1000
# IS_BIDIRECTIONAL=True
# K_EVAL=20
# LOSS_TYPE=TOP1
# LR=0.03
# MODEL_NAME=GRU4REC-CrossEntropy
# MOMENTUM=0
# N_EPOCHS=10
# NUM_LAYERS=1
# OPTIMIZER_TYPE=Adagrad
# SAVE_DIR=models
# SEED=22
# SIGMA=None
# TIME_SORT=False
# TRAIN_DATA=train.txt
# VALID_DATA=valid.txt
# WEIGHT_DECAY=0
# -------------------
# ...
