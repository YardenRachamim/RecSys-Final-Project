# %% [markdown]
# # Evaluating Yoochoose data

# %% [markdown]
# **Evaluating GRU4REC Anchor model on yoochoose data with the best hyper params**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python '/content/drive/MyDrive/RecSys/FinalProject/src/eval.py' --data_folder "/content/drive/MyDrive/RecSys/FinalProject/data/youchoose" --load_model '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_yoochhose/one direction/02181434/model_00004.pt'
# Out:
# evaluation
# BATCH_SIZE=50
#
# LOSS_TYPE=TOP1-max
#
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/valid.txt
# Loading pre-trained model from /content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_yoochhose/one direction/02181434/model_00004.pt
# 100% 1112/1117 [00:03<00:00, 352.94it/s]
# Final result: recall = 0.62, mrr = 0.27

# %% [markdown]
# **Evaluating Bidirectional GRU4REC on yoochoose data, with the best hyper params**
#
#
# ---

# %%
# !python '/content/drive/MyDrive/RecSys/FinalProject/src/eval.py' --data_folder "/content/drive/MyDrive/RecSys/FinalProject/data/youchoose" --load_model '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_yoochhose/bi-directional/02151002/model_00004.pt'
# Out:
# evaluation
# BATCH_SIZE=50
#
# LOSS_TYPE=TOP1-max
#
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/valid.txt
# Loading pre-trained model from /content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_yoochhose/bi-directional/02151002/model_00004.pt
# 100% 1112/1117 [00:03<00:00, 345.87it/s]
# Final result: recall = 0.63, mrr = 0.28

# %% [markdown]
# **Evaluating S-POP for Yoochoose data**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train_s_pop.py"
# Out:
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/youchoose/valid.txt
# 100% 15324/15324 [01:52<00:00, 135.69it/s]
# recall: 0.2692404021610791, mrr: 0.17937729272376557

# %% [markdown]
# # Evaluating Digenetica data

# %% [markdown]
# **Evaluating GRU4REC Anchor model on Digenetica data, with the best hyper params**

# %%
# !python '/content/drive/MyDrive/RecSys/FinalProject/src/eval.py' --data_folder "/content/drive/MyDrive/RecSys/FinalProject/data/digenetica" --load_model '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/one direction/02190941/model_00009.pt'
# Out:
# evaluation
# BATCH_SIZE=512
#
# LOSS_TYPE=TOP1
#
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/valid.txt
# Loading pre-trained model from /content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/one direction/02190941/model_00009.pt
#  81% 13/16 [00:00<00:00, 25.54it/s]
# Final result: recall = 0.41, mrr = 0.12

# %% [markdown]
# **Evaluating Bidirectional GRU4REC on Digenetica data, with the best hyper params**
#
#
# ---

# %%
# !python '/content/drive/MyDrive/RecSys/FinalProject/src/eval.py' --data_folder "/content/drive/MyDrive/RecSys/FinalProject/data/digenetica" --load_model '/content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/bi-directional/02191031/model_00009.pt'
# Out:
# evaluation
# BATCH_SIZE=512
#
# LOSS_TYPE=TOP1
#
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/valid.txt
# Loading pre-trained model from /content/drive/MyDrive/RecSys/FinalProject/models/checkpoint_digenetica/bi-directional/02191031/model_00009.pt
#  81% 13/16 [00:00<00:00, 14.22it/s]
# Final result: recall = 0.44, mrr = 0.13

# %% [markdown]
# **Evaluating S-POP for Digenetica data**

# %%
# !python "/content/drive/MyDrive/RecSys/FinalProject/src/train_s_pop.py" --data_folder "/content/drive/MyDrive/RecSys/FinalProject/data/digenetica"
# Out:
# Loading train data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/train.txt
# Loading valid data from /content/drive/MyDrive/RecSys/FinalProject/data/digenetica/valid.txt
# 100% 2175/2175 [00:15<00:00, 136.29it/s]
# recall: 0.22701983551040156, mrr: 0.14599364415085078
